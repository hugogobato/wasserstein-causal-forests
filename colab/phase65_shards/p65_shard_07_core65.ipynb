# %% [markdown]
# # Phase 6.5 shard 07 (core65)
#
# Runs **30 cells** of the frozen Phase 6.5 manifest (`G3-PHASE65-v1`), covering: `cwdb_dr`, `cwdb_r3_cvridge`, `cwdb_zipt`.
#
# This shard runs the pure-Python methods: the cross-fitted R3 booster, the doubly-robust calibration layer, and the two-part assembly. There is no install step, so computing starts immediately.
#
# Estimated single-threaded compute on the reference machine is about **85 minutes**. Colab cores are slower, so allow two to three times that, plus any install time above. This fits comfortably inside a nine hour session.
#
# **Run every cell in order.** The last cell downloads a `.zip`; collect every shard's zip into `results/phase65/colab_shards/` (logs into `results/manifests/`) and run `python research/run_phase65.py merge`.

# %%
# Thread pinning MUST happen before NumPy or SciPy are imported.
# OpenMP sizes its pool at initialisation, so setting these
# afterwards is silently ineffective.
import os
for _v in ('OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS',
           'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS',
           'VECLIB_MAXIMUM_THREADS', 'R_NUM_THREADS'):
    os.environ[_v] = '1'
print('threads pinned to 1')

# %% [markdown]
# ## 1. Clone the repository at the pinned commit
#
# Remote `https://github.com/hugogobato/wasserstein-causal-forests.git`, commit `5f3b2ad66b0b`. After checkout the notebook asserts the frozen manifest checksum, so a clone of anything but the generating commit fails here rather than mid-run.

# %%
import subprocess, pathlib, os, sys, json, hashlib

REPO = 'https://github.com/hugogobato/wasserstein-causal-forests.git'
COMMIT = '5f3b2ad66b0b05c8f8fed19e0d849d75a206cbe8'
EXPECTED_CHECKSUM = '4e28d308ca99cde4c81379524fc4492a15b38f029b449899b0a307b6c0ace110'

workdir = pathlib.Path('/content/wcf')
if not workdir.exists():
    subprocess.run(['git', 'init', '-q', str(workdir)], check=True)
    subprocess.run(
        ['git', '-C', str(workdir), 'remote', 'add', 'origin', REPO],
        check=True,
    )
# A shallow fetch of the exact commit: nothing else is downloaded.
    subprocess.run(
        ['git', '-C', str(workdir), 'fetch', '-q', '--depth', '1',
         'origin', COMMIT], check=True,
    )
    subprocess.run(
        ['git', '-C', str(workdir), 'checkout', '-q', 'FETCH_HEAD'],
        check=True,
    )
os.chdir(workdir)
sys.path.insert(0, str(workdir / 'src'))

manifest = json.load(open(
    'results/manifests/phase65_manifest.json', encoding='utf-8'
))
checksum = hashlib.sha256(
    json.dumps(manifest['cells'], sort_keys=True).encode('utf-8')
).hexdigest()
assert checksum == EXPECTED_CHECKSUM, (
    'the cloned manifest does not match the frozen grid: '
    f'{checksum} != {EXPECTED_CHECKSUM}'
)
print('repo ready at commit ' + COMMIT[:12] + '; '
      + str(manifest['n_cells']) + ' frozen cells verified')

# %% [markdown]
# ## 2. Dependencies

# %%
# This group needs only NumPy, SciPy, scikit-learn and PyArrow, all
# preinstalled on Colab. Nothing to install.
# !python -c "import numpy, scipy, sklearn, pyarrow; print('numpy', numpy.__version__, '| sklearn', sklearn.__version__)"

# %% [markdown]
# ## 3. This shard's cells

# %%
import json, collections
SHARD_INDEX = 7
CELLS = json.loads('''[{"grid": "c_scaling", "dgp": "IC1", "n_train": 4000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 2, "cell_key": "2b82ca36241dad67", "test_seed": 900002}, {"grid": "d_ablation", "dgp": "DAskew", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 1, "cell_key": "a8aed567575e7f3c", "test_seed": 900001}, {"grid": "d_ablation", "dgp": "DAskew", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 7, "cell_key": "725325f673a51542", "test_seed": 900007}, {"grid": "d_ablation", "dgp": "DArand", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 9, "cell_key": "1d60bb00bed74cf6", "test_seed": 900009}, {"grid": "d_ablation", "dgp": "DAref", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 1, "cell_key": "2e3fedf2415bd7a1", "test_seed": 900001}, {"grid": "d_ablation", "dgp": "DAdim", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 3, "cell_key": "32aa4b2b2151bc7e", "test_seed": 900003}, {"grid": "e_zi", "dgp": "ZI0", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 5, "cell_key": "5bfb2126f9606e23", "test_seed": 900005}, {"grid": "e_zi", "dgp": "ZI1", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 7, "cell_key": "465874b84617f724", "test_seed": 900007}, {"grid": "e_zi", "dgp": "ZI2", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 9, "cell_key": "c88e3172250af063", "test_seed": 900009}, {"grid": "e_zi", "dgp": "ZI0", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 1, "cell_key": "af26c9e9c0a66adb", "test_seed": 900001}, {"grid": "e_zi", "dgp": "ZI1", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 3, "cell_key": "f462f47bebaafe11", "test_seed": 900003}, {"grid": "e_zi", "dgp": "ZI2", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 5, "cell_key": "ab8554c4c0a47f08", "test_seed": 900005}, {"grid": "e_zi", "dgp": "ZI3", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 7, "cell_key": "ee38499eb398e584", "test_seed": 900007}, {"grid": "d_ablation", "dgp": "DArand", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 1, "cell_key": "1c16f4f1df7ccdde", "test_seed": 900001}, {"grid": "d_ablation", "dgp": "DAunit", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 3, "cell_key": "f15d2cc111b5ed0d", "test_seed": 900003}, {"grid": "d_ablation", "dgp": "DAref", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 5, "cell_key": "74838ef359000a0a", "test_seed": 900005}, {"grid": "d_ablation", "dgp": "DAdim", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 7, "cell_key": "2f1d9c85cbccf3d7", "test_seed": 900007}, {"grid": "e_zi", "dgp": "ZI0", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 9, "cell_key": "499f7ffe2470598d", "test_seed": 900009}, {"grid": "e_zi", "dgp": "ZI2", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 1, "cell_key": "f032f38100d1a57c", "test_seed": 900001}, {"grid": "e_zi", "dgp": "ZI3", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 3, "cell_key": "7898dff9922bac60", "test_seed": 900003}, {"grid": "e_zi", "dgp": "ZI0", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_zipt", "seed": 5, "cell_key": "ebad430c9f385be6", "test_seed": 900005}, {"grid": "e_zi", "dgp": "ZI1", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_zipt", "seed": 7, "cell_key": "45ac1fe07a78af74", "test_seed": 900007}, {"grid": "e_zi", "dgp": "ZI2", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_zipt", "seed": 9, "cell_key": "af7cd5cf50951082", "test_seed": 900009}, {"grid": "e_zi", "dgp": "ZI0", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_zipt", "seed": 1, "cell_key": "f251d64500a1111c", "test_seed": 900001}, {"grid": "e_zi", "dgp": "ZI1", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_zipt", "seed": 3, "cell_key": "1d4d2448a1f67607", "test_seed": 900003}, {"grid": "e_zi", "dgp": "ZI2", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_zipt", "seed": 5, "cell_key": "b3dc52b82119d453", "test_seed": 900005}, {"grid": "e_zi", "dgp": "ZI3", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_zipt", "seed": 7, "cell_key": "99c76437e97e1e83", "test_seed": 900007}, {"grid": "e_zi", "dgp": "ZI1", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 5, "cell_key": "edfa192583ac7492", "test_seed": 900005}, {"grid": "e_zi", "dgp": "ZI2", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 7, "cell_key": "f9b1cdf786b358d8", "test_seed": 900007}, {"grid": "e_zi", "dgp": "ZI3", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 9, "cell_key": "3e99573cbee224e3", "test_seed": 900009}]''')
print(f'{len(CELLS)} cells in this shard')
for key, count in sorted(collections.Counter(
        (c['grid'], c['dgp'], c['method'])
        for c in CELLS).items()):
    print(f'  {key[0]:12s} {key[1]:8s} {key[2]:18s} {count}')

# %% [markdown]
# ## 4. Run

# %%
import time
from pathlib import Path
from wasserstein_causal_forests.g3.manifest import Cell
from wasserstein_causal_forests.g3.runner import run_shard

cells = [Cell(**{k: v for k, v in item.items()
                 if k not in ('cell_key', 'test_seed')})
         for item in CELLS]

out = Path('/content/wcf/results/phase65/colab_shards')
out.mkdir(parents=True, exist_ok=True)
log = Path(f'/content/wcf/results/manifests/phase65_execution_log_{SHARD_INDEX:03d}.jsonl')
log.parent.mkdir(parents=True, exist_ok=True)
cache = Path('/content/wcf/results/rcpp_cache')
cache.mkdir(parents=True, exist_ok=True)

started = time.time()
summary = run_shard(
    cells,
    out / f'shard_{SHARD_INDEX:03d}.parquet',
    cache_directory=cache,
    log_path=log,
    manifest_contract_id='G3-PHASE65-v1',
)
print(json.dumps(summary, indent=2))
print(f'elapsed {(time.time() - started) / 60:.1f} min')

# %% [markdown]
# ## Check
#
# Every cell must appear exactly once, as a success or as a failure. Failures are kept and reported at merge time; a seed is never silently replaced.

# %%
import collections
records = [json.loads(line) for line in
           open(log, encoding='utf-8') if line.strip()]
status = collections.Counter(r['status'] for r in records)
print('cells logged:', len(records), '| expected:', len(CELLS))
print('status:', dict(status))
assert len(records) == len(CELLS), 'shard did not finish every cell'
for record in records:
    if record['status'] != 'ok':
        print('  FAILED', record['dgp'], record['method'],
              record['seed'])
slowest = sorted(records, key=lambda r: -r['wall_seconds'])[:5]
print('slowest cells:', [(r['method'], round(r['wall_seconds'], 1))
                         for r in slowest])

# %% [markdown]
# ## Download the results

# %%
import shutil
bundle = '/content/p65_shard_07_core65'
staging = Path('/content/bundle')
if staging.exists():
    shutil.rmtree(staging)
staging.mkdir(parents=True)
shutil.copy(out / f'shard_{SHARD_INDEX:03d}.parquet', staging)
if log.exists():
    shutil.copy(log, staging)
output_file = shutil.make_archive(bundle, 'zip', staging)
print('bundle:', output_file,
      f'({os.path.getsize(output_file) / 1e6:.2f} MB)')

try:
    from google.colab import files
    files.download(output_file)
    print('Downloaded:', output_file)
except Exception as e:
    print('(Not on Colab / download skipped):', e)
