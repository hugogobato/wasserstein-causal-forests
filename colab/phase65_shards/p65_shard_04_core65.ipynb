# %% [markdown]
# # Phase 6.5 shard 04 (core65)
#
# Runs **30 cells** of the frozen Phase 6.5 manifest (`G3-PHASE65-v1`), covering: `cwdb_dr`, `cwdb_r3_cvridge`, `cwdb_zipt`.
#
# This shard runs the pure-Python methods: the cross-fitted R3 booster, the doubly-robust calibration layer, and the two-part assembly. There is no install step, so computing starts immediately.
#
# Estimated single-threaded compute on the reference machine is about **84 minutes**. Colab cores are slower, so allow two to three times that, plus any install time above. This fits comfortably inside a nine hour session.
#
# **Run every cell in order.** The last cell downloads a `.zip`; collect every shard's zip into `results/phase65/colab_shards/` (logs into `results/manifests/`) and run `python research/run_phase65.py merge`.

# %%
# Thread pinning MUST happen before NumPy or SciPy are imported.
# OpenMP sizes its pool at initialisation, so setting these
# afterwards is silently ineffective.
import os
for _v in ('OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS',
           'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS',
           'VECLIB_MAXIMUM_THREADS', 'R_NUM_THREADS'):
    os.environ[_v] = '1'
print('threads pinned to 1')

# %% [markdown]
# ## 1. Clone the repository at the pinned commit
#
# Remote `https://github.com/hugogobato/wasserstein-causal-forests.git`, commit `bfe99cb3f305`. After checkout the notebook asserts the frozen manifest checksum, so a clone of anything but the generating commit fails here rather than mid-run.

# %%
import subprocess, pathlib, os, sys, json, hashlib

REPO = 'https://github.com/hugogobato/wasserstein-causal-forests.git'
COMMIT = 'bfe99cb3f305d5f9372dfb723888ed128b8f6ed9'
EXPECTED_CHECKSUM = '4e28d308ca99cde4c81379524fc4492a15b38f029b449899b0a307b6c0ace110'

workdir = pathlib.Path('/content/wcf')
if not workdir.exists():
    subprocess.run(['git', 'init', '-q', str(workdir)], check=True)
    subprocess.run(
        ['git', '-C', str(workdir), 'remote', 'add', 'origin', REPO],
        check=True,
    )
# A shallow fetch of the exact commit: nothing else is downloaded.
    subprocess.run(
        ['git', '-C', str(workdir), 'fetch', '-q', '--depth', '1',
         'origin', COMMIT], check=True,
    )
    subprocess.run(
        ['git', '-C', str(workdir), 'checkout', '-q', 'FETCH_HEAD'],
        check=True,
    )
os.chdir(workdir)
sys.path.insert(0, str(workdir / 'src'))

manifest = json.load(open(
    'results/manifests/phase65_manifest.json', encoding='utf-8'
))
checksum = hashlib.sha256(
    json.dumps(manifest['cells'], sort_keys=True).encode('utf-8')
).hexdigest()
assert checksum == EXPECTED_CHECKSUM, (
    'the cloned manifest does not match the frozen grid: '
    f'{checksum} != {EXPECTED_CHECKSUM}'
)
print('repo ready at commit ' + COMMIT[:12] + '; '
      + str(manifest['n_cells']) + ' frozen cells verified')

# %% [markdown]
# ## 2. Dependencies

# %%
# This group needs only NumPy, SciPy, scikit-learn and PyArrow, all
# preinstalled on Colab. Nothing to install.
# !python -c "import numpy, scipy, sklearn, pyarrow; print('numpy', numpy.__version__, '| sklearn', sklearn.__version__)"

# %% [markdown]
# ## 3. This shard's cells

# %%
import json, collections
SHARD_INDEX = 4
CELLS = json.loads('''[{"grid": "c_scaling", "dgp": "IC0", "n_train": 4000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 4, "cell_key": "c538900a6e18fe77", "test_seed": 900004}, {"grid": "c_scaling", "dgp": "IC1", "n_train": 2000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 3, "cell_key": "46d03b45ffb681bc", "test_seed": 900003}, {"grid": "d_ablation", "dgp": "DArand", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 6, "cell_key": "d279c9f5829eff15", "test_seed": 900006}, {"grid": "d_ablation", "dgp": "DAunit", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 8, "cell_key": "eb8e01e76572007f", "test_seed": 900008}, {"grid": "d_ablation", "dgp": "DAdim", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 0, "cell_key": "61ca60135ec2ddc5", "test_seed": 900000}, {"grid": "e_zi", "dgp": "ZI0", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 2, "cell_key": "194ba9ffc2cf84f0", "test_seed": 900002}, {"grid": "e_zi", "dgp": "ZI1", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 4, "cell_key": "0fff382553923e64", "test_seed": 900004}, {"grid": "e_zi", "dgp": "ZI2", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 6, "cell_key": "cf5fbf38a20aac1c", "test_seed": 900006}, {"grid": "e_zi", "dgp": "ZI3", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 8, "cell_key": "c5f81a2589338499", "test_seed": 900008}, {"grid": "e_zi", "dgp": "ZI1", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 0, "cell_key": "7476ce757085c9a8", "test_seed": 900000}, {"grid": "e_zi", "dgp": "ZI2", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 2, "cell_key": "606b6407bb7f006f", "test_seed": 900002}, {"grid": "e_zi", "dgp": "ZI3", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_dr", "seed": 4, "cell_key": "8ddbbf8226593386", "test_seed": 900004}, {"grid": "d_ablation", "dgp": "DAskew", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 6, "cell_key": "ee970bc8f04878a6", "test_seed": 900006}, {"grid": "d_ablation", "dgp": "DArand", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 8, "cell_key": "eae1b1fabaaff155", "test_seed": 900008}, {"grid": "d_ablation", "dgp": "DAref", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 0, "cell_key": "d43be9b1e8133307", "test_seed": 900000}, {"grid": "d_ablation", "dgp": "DAdim", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 2, "cell_key": "71102f468bbc08f8", "test_seed": 900002}, {"grid": "e_zi", "dgp": "ZI0", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 4, "cell_key": "7c93cfb382a29b1c", "test_seed": 900004}, {"grid": "e_zi", "dgp": "ZI1", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 6, "cell_key": "dd7b37bd530720f5", "test_seed": 900006}, {"grid": "e_zi", "dgp": "ZI2", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 8, "cell_key": "143013754face4e8", "test_seed": 900008}, {"grid": "e_zi", "dgp": "ZI0", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_zipt", "seed": 0, "cell_key": "8875202d611ecce8", "test_seed": 900000}, {"grid": "e_zi", "dgp": "ZI0", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_zipt", "seed": 8, "cell_key": "164b023797985c74", "test_seed": 900008}, {"grid": "e_zi", "dgp": "ZI2", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_zipt", "seed": 0, "cell_key": "a85e1c3173fc69e2", "test_seed": 900000}, {"grid": "e_zi", "dgp": "ZI3", "n_train": 1000, "n_grid": 25, "n_particles": 10, "method": "cwdb_zipt", "seed": 2, "cell_key": "fa39535e9c92215e", "test_seed": 900002}, {"grid": "e_zi", "dgp": "ZI0", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_zipt", "seed": 4, "cell_key": "00f457ba38d3e29e", "test_seed": 900004}, {"grid": "e_zi", "dgp": "ZI1", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_zipt", "seed": 6, "cell_key": "5c860640b68b9b0a", "test_seed": 900006}, {"grid": "e_zi", "dgp": "ZI2", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_zipt", "seed": 8, "cell_key": "a6b1e78f44888d9a", "test_seed": 900008}, {"grid": "e_zi", "dgp": "ZI0", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 0, "cell_key": "64bfc4644f4fd215", "test_seed": 900000}, {"grid": "e_zi", "dgp": "ZI0", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 8, "cell_key": "abb921542c9a27db", "test_seed": 900008}, {"grid": "e_zi", "dgp": "ZI2", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 0, "cell_key": "f472fd35f68d2401", "test_seed": 900000}, {"grid": "e_zi", "dgp": "ZI3", "n_train": 500, "n_grid": 25, "n_particles": 10, "method": "cwdb_r3_cvridge", "seed": 2, "cell_key": "417f3006ffbbe89c", "test_seed": 900002}]''')
print(f'{len(CELLS)} cells in this shard')
for key, count in sorted(collections.Counter(
        (c['grid'], c['dgp'], c['method'])
        for c in CELLS).items()):
    print(f'  {key[0]:12s} {key[1]:8s} {key[2]:18s} {count}')

# %% [markdown]
# ## 4. Run

# %%
import time
from pathlib import Path
from wasserstein_causal_forests.g3.manifest import Cell
from wasserstein_causal_forests.g3.runner import run_shard

cells = [Cell(**{k: v for k, v in item.items()
                 if k not in ('cell_key', 'test_seed')})
         for item in CELLS]

out = Path('/content/wcf/results/phase65/colab_shards')
out.mkdir(parents=True, exist_ok=True)
log = Path(f'/content/wcf/results/manifests/phase65_execution_log_{SHARD_INDEX:03d}.jsonl')
log.parent.mkdir(parents=True, exist_ok=True)
cache = Path('/content/wcf/results/rcpp_cache')
cache.mkdir(parents=True, exist_ok=True)

started = time.time()
summary = run_shard(
    cells,
    out / f'shard_{SHARD_INDEX:03d}.parquet',
    cache_directory=cache,
    log_path=log,
    manifest_contract_id='G3-PHASE65-v1',
)
print(json.dumps(summary, indent=2))
print(f'elapsed {(time.time() - started) / 60:.1f} min')

# %% [markdown]
# ## Check
#
# Every cell must appear exactly once, as a success or as a failure. Failures are kept and reported at merge time; a seed is never silently replaced.

# %%
import collections
records = [json.loads(line) for line in
           open(log, encoding='utf-8') if line.strip()]
status = collections.Counter(r['status'] for r in records)
print('cells logged:', len(records), '| expected:', len(CELLS))
print('status:', dict(status))
assert len(records) == len(CELLS), 'shard did not finish every cell'
for record in records:
    if record['status'] != 'ok':
        print('  FAILED', record['dgp'], record['method'],
              record['seed'])
slowest = sorted(records, key=lambda r: -r['wall_seconds'])[:5]
print('slowest cells:', [(r['method'], round(r['wall_seconds'], 1))
                         for r in slowest])

# %% [markdown]
# ## Download the results

# %%
import shutil
bundle = '/content/p65_shard_04_core65'
staging = Path('/content/bundle')
if staging.exists():
    shutil.rmtree(staging)
staging.mkdir(parents=True)
shutil.copy(out / f'shard_{SHARD_INDEX:03d}.parquet', staging)
if log.exists():
    shutil.copy(log, staging)
output_file = shutil.make_archive(bundle, 'zip', staging)
print('bundle:', output_file,
      f'({os.path.getsize(output_file) / 1e6:.2f} MB)')

try:
    from google.colab import files
    files.download(output_file)
    print('Downloaded:', output_file)
except Exception as e:
    print('(Not on Colab / download skipped):', e)
